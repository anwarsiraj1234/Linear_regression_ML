# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv(r"iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
# linear agression  model , train data set, test data set.

# %%
category_mapping = {'setosa': 0, 'versicolor': 1, 'virginica': 2}
df['species'] = df['species'].map(category_mapping)

# %%
x = df.drop(["species"],axis = 1)
y = df[["species"]]
x1 = df["sepal_length"]

# %%
y.tail
# Out:
# <bound method NDFrame.tail of      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]>

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10,6))
plt.scatter(x1,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10,6))
plt.scatter(x['sepal_width'],y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10,6))
plt.scatter(x['petal_length'],y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10,6))
plt.scatter(x['petal_width'],y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 137           6.4          3.1           5.5          1.8
# 84            5.4          3.0           4.5          1.5
# 27            5.2          3.5           1.5          0.2
# 127           6.1          3.0           4.9          1.8
# 132           6.4          2.8           5.6          2.2
# ..            ...          ...           ...          ...
# 9             4.9          3.1           1.5          0.1
# 103           6.3          2.9           5.6          1.8
# 67            5.8          2.7           4.1          1.0
# 117           7.7          3.8           6.7          2.2
# 47            4.6          3.2           1.4          0.2
#
# [120 rows x 4 columns]

# %%
y_train
# Out:
#      species
# 137        2
# 84         1
# 27         0
# 127        2
# 132        2
# ..       ...
# 9          0
# 103        2
# 67         1
# 117        2
# 47         0
#
# [120 rows x 1 columns]

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 114           5.8          2.8           5.1          2.4
# 62            6.0          2.2           4.0          1.0
# 33            5.5          4.2           1.4          0.2
# 107           7.3          2.9           6.3          1.8
# 7             5.0          3.4           1.5          0.2
# 100           6.3          3.3           6.0          2.5
# 40            5.0          3.5           1.3          0.3
# 86            6.7          3.1           4.7          1.5
# 76            6.8          2.8           4.8          1.4
# 71            6.1          2.8           4.0          1.3
# 134           6.1          2.6           5.6          1.4
# 51            6.4          3.2           4.5          1.5
# 73            6.1          2.8           4.7          1.2
# 54            6.5          2.8           4.6          1.5
# 63            6.1          2.9           4.7          1.4
# ...

# %%
y_test
# Out:
#      species
# 114        2
# 62         1
# 33         0
# 107        2
# 7          0
# 100        2
# 40         0
# 86         1
# 76         1
# 71         1
# 134        2
# 51         1
# 73         1
# 54         1
# 63         1
# 37         0
# 78         1
# 90         1
# 45         0
# 16         0
# 121        2
# 66         1
# 24         0
# 8          0
# 126        2
# 22         0
# 44         0
# 97         1
# 93         1
# 26         0

# %%
r1 = LinearRegression()

# %%
r1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
r1.predict(x_test)
# Out:
# array([[ 2.06703909],
#        [ 0.96488074],
#        [-0.14594224],
#        [ 1.81373137],
#        [-0.03780827],
#        [ 2.26136881],
#        [-0.02684168],
#        [ 1.3195563 ],
#        [ 1.28300114],
#        [ 1.11288966],
#        [ 1.54909827],
#        [ 1.30153965],
#        [ 1.2127103 ],
#        [ 1.32986888],
#        [ 1.33047544],
#        [-0.07605449],
#        [ 1.35607655],
#        [ 1.21563955],
#        [ 0.0373887 ],
#        [-0.02449662],
#        [ 1.79885764],
#        [ 1.3946086 ],
#        [ 0.07528911],
#        [ 0.02303999],
#        [ 1.59033372],
#        [-0.11806588],
#        [ 0.14915066],
#        [ 1.1671282 ],
#        [ 0.90650885],
#        [ 0.10691577]])

# %%
r1.intercept_
# Out:
# array([0.16376703])

# %%
r1.coef_[0][0]
# Out:
# -0.10633314188200163

# %% [markdown]
# <!-- now verify the output -->

# %%
# y=b+mx
y1=0.16376703+5.8*-0.10633314+2.8*-0.10633314+5.1*0.22957688+2.4*0.60883174

# %%
y1
# Out:
# 1.8813402899999998

# %%
# #Reading R-square value (the goodness of fit)

r1.score(x_test,y_test)
# Out:
# 0.9059663899067815

# %%
r1.score(x_train,y_train)
# Out:
# 0.9339533279460861

# %%
x_test_1=x_test['sepal_length']

# %%
#Plotting the fit line ovr the scatter plot
plt.figure(figsize=(10,6))
plt.scatter(x_test_1,y_test,alpha=0.3)
# plt.title('Budget vs Revenue',fontsize=14)
# plt.xlabel('Movie Budget $',fontsize=14)
# plt.ylabel('Movie bRvenue $',fontsize=14)
plt.xticks(color='red',fontsize=14)
# plt.xlim(0,450000000)
# plt.ylim(0,1000000000)
plt.plot(x_test,r1.predict(x_test),color='red',linewidth=4)
plt.show()

# %%
# This grapgh is bc the baove dataset was not linear
